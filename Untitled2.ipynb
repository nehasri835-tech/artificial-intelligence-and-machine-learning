# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Sample dataset
data = {
    "message": [
        "Congratulations! You won a free iPhone",
        "Meeting at 10 AM tomorrow",
        "Claim your lottery prize now",
        "Please submit the project report",
        "Win cash reward instantly",
        "Lunch at 1 PM today",
        "Exclusive offer! Click here",
        "Team meeting is postponed"
    ],
    "label": [
        "spam",
        "ham",
        "spam",
        "ham",
        "spam",
        "ham",
        "spam",
        "ham"
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and Labels
X = df["message"]
y = df["label"]

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Convert text to numbers
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Train model
model = MultinomialNB()
model.fit(X_train, y_train)

# Test accuracy
predictions = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, predictions))

# Predict new message
new_message = ["Congratulations! You have won $1000 cash"]
new_vector = vectorizer.transform(new_message)
result = model.predict(new_vector)

print("Prediction:", result[0])
# Out:
# Accuracy: 0.5
# Prediction: spam
